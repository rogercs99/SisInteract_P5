# %% [markdown]
# <a href="https://colab.research.google.com/github/rogercs99/SisInteract_P5/blob/master/TexScaling_ESRGAN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ==========================================
# 0⃣  MONTA GOOGLE DRIVE
# ==========================================
from google.colab import drive
from subprocess import CalledProcessError, TimeoutExpired, run as sp_run
print("📀 Montando Google Drive…")
drive.mount('/content/drive')
print("✅ Drive montado.\n")

# ==========================================
# 1⃣  RUTAS BÁSICAS
# ==========================================
import os, json, time, shutil, datetime, subprocess, pathlib, uuid

BASE_DIR   = '/content/drive/MyDrive/TexScaling/Real-ESRGAN'
INPUT_ROOT = os.path.join(BASE_DIR, 'upload')
OUTPUT_ROOT= os.path.join(BASE_DIR, 'results')

print("📂 Rutas clave:")
print(f"   BASE_DIR   ➜ {BASE_DIR}")
print(f"   INPUT_ROOT ➜ {INPUT_ROOT}")
print(f"   OUTPUT_ROOT➜ {OUTPUT_ROOT}")

os.makedirs(INPUT_ROOT,  exist_ok=True)
os.makedirs(OUTPUT_ROOT, exist_ok=True)

# %cd "{BASE_DIR}"

print("📦 Instalando dependencias (basicsr, facexlib, gfpgan)…")
# !pip install -q basicsr facexlib gfpgan
print("📝 Instalando requirements.txt …")
# !pip install -q -r requirements.txt
print("🔧 Instalando Real-ESRGAN en modo develop…")
# !python setup.py -q develop
print("✅ Dependencias listas.\n")

# --- parche torchvision (Python 3.11) ---
patch_file = '/usr/local/lib/python3.11/dist-packages/basicsr/data/degradations.py'
old = 'from torchvision.transforms.functional_tensor import rgb_to_grayscale'
new = 'from torchvision.transforms.functional import rgb_to_grayscale'

if pathlib.Path(patch_file).exists():
    txt = pathlib.Path(patch_file).read_text()
    if old in txt:
        print("🩹 Parchando torchvision import en degradations.py…")
        pathlib.Path(patch_file).write_text(txt.replace(old, new))
        print("✅ Parche aplicado.\n")
    else:
        print("ℹ️  Parche ya aplicado previamente.\n")
else:
    print("⚠️  Archivo de parche no encontrado, continuamos.\n")

# ==========================================
# 3⃣  FUNCIÓN QUE PROCESA UNA CARPETA (con control robusto de errores)
# ==========================================
ESRGAN_TIMEOUT = 30 * 60          # ⏲️  30 min por carpeta (ajusta según tu GPU)
PRINT_CHUNK    = 200              # nº de primeros caracteres del stderr que se muestran

def run_esrgan_for(tx_id: str) -> bool:
    print(f"\n🔍 Revisando carpeta {tx_id}")
    in_dir       = os.path.join("upload", tx_id)        # relativa para ES RGAN
    out_dir      = os.path.join("results", tx_id)
    in_full      = os.path.join(INPUT_ROOT, tx_id)      # absoluta en Drive
    status_in    = os.path.join(in_full, 'status.json')
    log_fp       = os.path.join(out_dir, 'esrgan.log')
    output_full  = os.path.join(OUTPUT_ROOT, tx_id)
    status_out   = os.path.join(output_full, 'status.json')
    tmp_input    = f"/tmp/{tx_id}_imgs"                 # carpeta temporal solo imágenes
    tmp_output   = f"/tmp/{tx_id}_out"                  # carpeta temporal para ESRGAN

    print(f"   ↳ in_dir    : {in_dir}")
    print(f"   ↳ out_dir   : {out_dir}")
    print(f"   ↳ status_in : {status_in}")

    # 1) Leer status.json en input
    try:
        with open(status_in, 'r') as f:
            status = json.load(f)
        print(f"   ↳ Estado actual: {status.get('status')}")
    except Exception as e:
        print(f"   ❌ Error leyendo status.json → {e}")
        return False

    if status.get('status') != 'ready_to_process':
        print("   🚫 Estado ≠ ready_to_process, saltando.\n")
        return False

    # 2) Marcar "processing" en input
    status['status'] = 'processing'
    with open(status_in, 'w') as f:
        json.dump(status, f, indent=2)
    print("   ✍️  Marcado como processing en input.")

    # 3) Preparar carpeta temporal con solo imágenes
    print("   📂 Preparando carpeta temporal con solo imágenes")
    if os.path.exists(tmp_input):
        shutil.rmtree(tmp_input)
    os.makedirs(tmp_input, exist_ok=True)

    exts = (".png", ".jpg", ".jpeg")
    for fname in os.listdir(in_full):
        if fname.lower().endswith(exts):
            src = os.path.join(in_full, fname)
            dst = os.path.join(tmp_input, fname)
            shutil.copy2(src, dst)
            print(f"      ✔️ Copiado imagen: {fname}")
    print(f"   ➜ {len(os.listdir(tmp_input))} imágenes copiadas a {tmp_input}")

    # 4) Ejecutar Real-ESRGAN en tmp_input → tmp_output
    print("   🚀 Lanzando ESRGAN solo con imágenes")
    if os.path.exists(tmp_output):
        shutil.rmtree(tmp_output)
    os.makedirs(tmp_output, exist_ok=True)

    cmd = [
        'python',
        os.path.join(BASE_DIR, 'inference_realesrgan.py'),
        '-n', 'RealESRGAN_x4plus',
        '-i', tmp_input,
        '-o', tmp_output,
        '--outscale', '4',
        '--face_enhance'
    ]
    print(f"   ↳ Comando: {' '.join(cmd)} (timeout {ESRGAN_TIMEOUT}s)")

    try:
        result = subprocess.run(
            cmd,
            cwd=BASE_DIR,
            stdout=subprocess.PIPE,
            stderr=subprocess.PIPE,
            text=True,
            timeout=ESRGAN_TIMEOUT,
            check=False   # no interrumpir si exit != 0
        )
        # Guardar stdout+stderr en log
        os.makedirs(out_dir, exist_ok=True)
        with open(log_fp, 'w') as lf:
            lf.write(result.stdout)
            lf.write("\n--- STDERR ---\n")
            lf.write(result.stderr or "")

        if result.returncode == 0:
            print(f"   ✅ ESRGAN completó para {tx_id}")
        else:
            snippet = (result.stderr or "")[:PRINT_CHUNK]
            print(f"   ⚠️  ESRGAN exit {result.returncode}, continuando. "
                  f"Primeros {PRINT_CHUNK} chars stderr:\n{snippet}\n")
    except subprocess.TimeoutExpired as e:
        print(f"   ⏱️  Timeout ({ESRGAN_TIMEOUT}s) alcanzado")
        with open(log_fp, 'w') as lf:
            lf.write(e.stdout or "")
            lf.write("\n--- STDERR ---\n")
            lf.write(e.stderr or "")
    except FileNotFoundError as e:
        print(f"   ❌ inference_realesrgan.py no encontrado → {e}")

    # 5) Copiar resultados temporales a carpeta final SIN sufijo "_out"
    print("   📂 Moviendo resultados a output sin sufijo _out")
    os.makedirs(out_dir, exist_ok=True)
    renamed_count = 0
    for fname in os.listdir(tmp_output):
        # Solo imágenes: terminan en .png .jpg .jpeg (Real-ESRGAN crea *_out.png etc)
        if any(fname.lower().endswith(ext) for ext in exts):
            # Remover suffix "_out"
            new_name = fname.replace('_out', '')
            src = os.path.join(tmp_output, fname)
            dst = os.path.join(out_dir, new_name)
            shutil.move(src, dst)
            renamed_count += 1
            print(f"      ✔️ Renombrado {fname} → {new_name}")
    print(f"   ➜ {renamed_count} archivos movidos a {out_dir}")

    # 6) Contar imágenes en input y output
    print("   🔢 Contando imágenes en input y output…")
    input_count = len([f for f in os.listdir(tmp_input) if f.lower().endswith(exts)])
    output_count = len([f for f in os.listdir(out_dir)    if f.lower().endswith(exts)])
    print(f"   ↳ Imágenes en tmp_input/{tx_id}: {input_count}")
    print(f"   ↳ Imágenes en output/{tx_id}:   {output_count}")

    # 7) Verificar igualdad de conteos
    status_to_write = {
        "processed_at": datetime.datetime.utcnow().isoformat() + 'Z',
        "log_file":     log_fp
    }
    if input_count != output_count:
        print(f"   ⚠️ Conteos desiguales: input({input_count}) ≠ output({output_count})")
        status_to_write.update({
            "status":     "error",
            "error_code": "count_mismatch",
            "error_msg":  f"Conteo input {input_count} != output {output_count}"
        })
    else:
        status_to_write["status"] = "processed"
        print("   ✅ Conteos iguales.")

    # 8) Escribir status.json en carpeta output
    os.makedirs(output_full, exist_ok=True)
    with open(status_out, 'w') as f:
        json.dump(status_to_write, f, indent=2)
    print(f"   ✍️  status.json escrito en output: {status_out}\n")

    # 9) Limpiar temporales locales
    shutil.rmtree(tmp_input)
    shutil.rmtree(tmp_output)

    return True


# ==========================================
# 4⃣  BUCLE PRINCIPAL (polling)
# ==========================================
POLL_SECS = 1
loop_n    = 0
print("👀 Escuchando nuevas carpetas en upload/ … (Ctrl+C para parar)\n")

try:
    while True:
        loop_n += 1
        print(f"🔄 Iteración #{loop_n} — listando subcarpetas…")
        ids = [d for d in os.listdir(INPUT_ROOT)
               if os.path.isdir(os.path.join(INPUT_ROOT, d))]
        print(f"   Carpeta(s) detectada(s): {ids or 'ninguna'}")

        worked = False
        for tx in ids:
            worked |= run_esrgan_for(tx)

        if not worked:
            print("   ⏳ Nada para procesar, esperando…\n")

        time.sleep(POLL_SECS)

except KeyboardInterrupt:
    print("\n🛑 Bucle detenido manualmente.")
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #2392 — listando subcarpetas…
#    Carpeta(s) detectada(s): ['d05756e5-bac2-4b99-b313-eacd4b067213']
#
# 🔍 Revisando carpeta d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ in_dir    : upload/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ out_dir   : results/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ status_in : /content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json
#    ↳ Estado actual: processing
#    🚫 Estado ≠ ready_to_process, saltando.
#
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #2393 — listando subcarpetas…
#    Carpeta(s) detectada(s): ['d05756e5-bac2-4b99-b313-eacd4b067213']
#
# 🔍 Revisando carpeta d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ in_dir    : upload/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ out_dir   : results/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ status_in : /content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json
#    ↳ Estado actual: processing
#    🚫 Estado ≠ ready_to_process, saltando.
#
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #2394 — listando subcarpetas…
#    Carpeta(s) detectada(s): ['d05756e5-bac2-4b99-b313-eacd4b067213']
#
# 🔍 Revisando carpeta d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ in_dir    : upload/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ out_dir   : results/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ status_in : /content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json
#    ↳ Estado actual: processing
#    🚫 Estado ≠ ready_to_process, saltando.
#
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #2395 — listando subcarpetas…
#    Carpeta(s) detectada(s): ['d05756e5-bac2-4b99-b313-eacd4b067213']
#
# 🔍 Revisando carpeta d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ in_dir    : upload/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ out_dir   : results/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ status_in : /content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json
#    ↳ Estado actual: processing
#    🚫 Estado ≠ ready_to_process, saltando.
#
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #2396 — listando subcarpetas…
#    Carpeta(s) detectada(s): ['d05756e5-bac2-4b99-b313-eacd4b067213']
#
# 🔍 Revisando carpeta d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ in_dir    : upload/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ out_dir   : results/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ status_in : /content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json
#    ↳ Estado actual: processing
#    🚫 Estado ≠ ready_to_process, saltando.
#
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #2397 — listando subcarpetas…
#    Carpeta(s) detectada(s): ['d05756e5-bac2-4b99-b313-eacd4b067213']
#
# 🔍 Revisando carpeta d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ in_dir    : upload/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ out_dir   : results/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ status_in : /content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json
#    ↳ Estado actual: processing
#    🚫 Estado ≠ ready_to_process, saltando.
#
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #2398 — listando subcarpetas…
#    Carpeta(s) detectada(s): ['d05756e5-bac2-4b99-b313-eacd4b067213']
#
# 🔍 Revisando carpeta d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ in_dir    : upload/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ out_dir   : results/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ status_in : /content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json
#    ↳ Estado actual: processing
#    🚫 Estado ≠ ready_to_process, saltando.
#
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #2399 — listando subcarpetas…
#    Carpeta(s) detectada(s): ['d05756e5-bac2-4b99-b313-eacd4b067213']
#
# 🔍 Revisando carpeta d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ in_dir    : upload/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ out_dir   : results/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ status_in : /content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json
#    ↳ Estado actual: processing
#    🚫 Estado ≠ ready_to_process, saltando.
#
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #2400 — listando subcarpetas…
#    Carpeta(s) detectada(s): ['d05756e5-bac2-4b99-b313-eacd4b067213']
#
# 🔍 Revisando carpeta d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ in_dir    : upload/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ out_dir   : results/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ status_in : /content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json
#    ↳ Estado actual: processing
#    🚫 Estado ≠ ready_to_process, saltando.
#
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #2401 — listando subcarpetas…
#    Carpeta(s) detectada(s): ['d05756e5-bac2-4b99-b313-eacd4b067213']
#
# 🔍 Revisando carpeta d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ in_dir    : upload/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ out_dir   : results/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ status_in : /content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json
#    ↳ Estado actual: processing
#    🚫 Estado ≠ ready_to_process, saltando.
#
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #2402 — listando subcarpetas…
#    Carpeta(s) detectada(s): ['d05756e5-bac2-4b99-b313-eacd4b067213']
#
# 🔍 Revisando carpeta d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ in_dir    : upload/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ out_dir   : results/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ status_in : /content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json
#    ↳ Estado actual: processing
#    🚫 Estado ≠ ready_to_process, saltando.
#
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #2403 — listando subcarpetas…
#    Carpeta(s) detectada(s): ['d05756e5-bac2-4b99-b313-eacd4b067213']
#
# 🔍 Revisando carpeta d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ in_dir    : upload/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ out_dir   : results/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ status_in : /content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json
#    ↳ Estado actual: processing
#    🚫 Estado ≠ ready_to_process, saltando.
#
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #2404 — listando subcarpetas…
#    Carpeta(s) detectada(s): ['d05756e5-bac2-4b99-b313-eacd4b067213']
#
# 🔍 Revisando carpeta d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ in_dir    : upload/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ out_dir   : results/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ status_in : /content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json
#    ↳ Estado actual: processing
#    🚫 Estado ≠ ready_to_process, saltando.
#
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #2405 — listando subcarpetas…
#    Carpeta(s) detectada(s): ['d05756e5-bac2-4b99-b313-eacd4b067213']
#
# 🔍 Revisando carpeta d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ in_dir    : upload/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ out_dir   : results/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ status_in : /content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json
#    ↳ Estado actual: processing
#    🚫 Estado ≠ ready_to_process, saltando.
#
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #2406 — listando subcarpetas…
#    Carpeta(s) detectada(s): ['d05756e5-bac2-4b99-b313-eacd4b067213']
#
# 🔍 Revisando carpeta d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ in_dir    : upload/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ out_dir   : results/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ status_in : /content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json
#    ↳ Estado actual: processing
#    🚫 Estado ≠ ready_to_process, saltando.
#
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #2407 — listando subcarpetas…
#    Carpeta(s) detectada(s): ['d05756e5-bac2-4b99-b313-eacd4b067213']
#
# 🔍 Revisando carpeta d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ in_dir    : upload/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ out_dir   : results/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ status_in : /content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json
#    ↳ Estado actual: processing
#    🚫 Estado ≠ ready_to_process, saltando.
#
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #2408 — listando subcarpetas…
#    Carpeta(s) detectada(s): ['d05756e5-bac2-4b99-b313-eacd4b067213']
#
# 🔍 Revisando carpeta d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ in_dir    : upload/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ out_dir   : results/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ status_in : /content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json
#    ❌ Error leyendo status.json → [Errno 2] No such file or directory: '/content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json'
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #2409 — listando subcarpetas…
#    Carpeta(s) detectada(s): ['d05756e5-bac2-4b99-b313-eacd4b067213']
#
# 🔍 Revisando carpeta d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ in_dir    : upload/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ out_dir   : results/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ status_in : /content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json
#    ❌ Error leyendo status.json → [Errno 2] No such file or directory: '/content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json'
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #2410 — listando subcarpetas…
#    Carpeta(s) detectada(s): ['d05756e5-bac2-4b99-b313-eacd4b067213']
#
# 🔍 Revisando carpeta d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ in_dir    : upload/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ out_dir   : results/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ status_in : /content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json
#    ❌ Error leyendo status.json → [Errno 2] No such file or directory: '/content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json'
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #2411 — listando subcarpetas…
#    Carpeta(s) detectada(s): ['d05756e5-bac2-4b99-b313-eacd4b067213']
#
# 🔍 Revisando carpeta d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ in_dir    : upload/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ out_dir   : results/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ status_in : /content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json
#    ❌ Error leyendo status.json → [Errno 2] No such file or directory: '/content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json'
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #2412 — listando subcarpetas…
#    Carpeta(s) detectada(s): ['d05756e5-bac2-4b99-b313-eacd4b067213']
#
# 🔍 Revisando carpeta d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ in_dir    : upload/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ out_dir   : results/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ status_in : /content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json
#    ❌ Error leyendo status.json → [Errno 2] No such file or directory: '/content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json'
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #2413 — listando subcarpetas…
#    Carpeta(s) detectada(s): ['d05756e5-bac2-4b99-b313-eacd4b067213']
#
# 🔍 Revisando carpeta d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ in_dir    : upload/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ out_dir   : results/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ status_in : /content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json
#    ❌ Error leyendo status.json → [Errno 2] No such file or directory: '/content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json'
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #2414 — listando subcarpetas…
#    Carpeta(s) detectada(s): ['d05756e5-bac2-4b99-b313-eacd4b067213']
#
# 🔍 Revisando carpeta d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ in_dir    : upload/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ out_dir   : results/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ status_in : /content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json
#    ❌ Error leyendo status.json → [Errno 2] No such file or directory: '/content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json'
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #2415 — listando subcarpetas…
#    Carpeta(s) detectada(s): ['d05756e5-bac2-4b99-b313-eacd4b067213']
#
# 🔍 Revisando carpeta d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ in_dir    : upload/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ out_dir   : results/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ status_in : /content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json
#    ❌ Error leyendo status.json → [Errno 2] No such file or directory: '/content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json'
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #2416 — listando subcarpetas…
#    Carpeta(s) detectada(s): ['d05756e5-bac2-4b99-b313-eacd4b067213']
#
# 🔍 Revisando carpeta d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ in_dir    : upload/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ out_dir   : results/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ status_in : /content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json
#    ❌ Error leyendo status.json → [Errno 2] No such file or directory: '/content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json'
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #2417 — listando subcarpetas…
#    Carpeta(s) detectada(s): ['d05756e5-bac2-4b99-b313-eacd4b067213']
#
# 🔍 Revisando carpeta d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ in_dir    : upload/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ out_dir   : results/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ status_in : /content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json
#    ❌ Error leyendo status.json → [Errno 2] No such file or directory: '/content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json'
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #2418 — listando subcarpetas…
#    Carpeta(s) detectada(s): ['d05756e5-bac2-4b99-b313-eacd4b067213']
#
# 🔍 Revisando carpeta d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ in_dir    : upload/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ out_dir   : results/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ status_in : /content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json
#    ❌ Error leyendo status.json → [Errno 2] No such file or directory: '/content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json'
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #2419 — listando subcarpetas…
#    Carpeta(s) detectada(s): ['d05756e5-bac2-4b99-b313-eacd4b067213']
#
# 🔍 Revisando carpeta d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ in_dir    : upload/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ out_dir   : results/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ status_in : /content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json
#    ❌ Error leyendo status.json → [Errno 2] No such file or directory: '/content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json'
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #2420 — listando subcarpetas…
#    Carpeta(s) detectada(s): ['d05756e5-bac2-4b99-b313-eacd4b067213']
#
# 🔍 Revisando carpeta d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ in_dir    : upload/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ out_dir   : results/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ status_in : /content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json
#    ❌ Error leyendo status.json → [Errno 2] No such file or directory: '/content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json'
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #2421 — listando subcarpetas…
#    Carpeta(s) detectada(s): ['d05756e5-bac2-4b99-b313-eacd4b067213']
#
# 🔍 Revisando carpeta d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ in_dir    : upload/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ out_dir   : results/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ status_in : /content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json
#    ❌ Error leyendo status.json → [Errno 2] No such file or directory: '/content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json'
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #2422 — listando subcarpetas…
#    Carpeta(s) detectada(s): ['d05756e5-bac2-4b99-b313-eacd4b067213']
#
# 🔍 Revisando carpeta d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ in_dir    : upload/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ out_dir   : results/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ status_in : /content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json
#    ❌ Error leyendo status.json → [Errno 2] No such file or directory: '/content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json'
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #2423 — listando subcarpetas…
#    Carpeta(s) detectada(s): ['d05756e5-bac2-4b99-b313-eacd4b067213']
#
# 🔍 Revisando carpeta d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ in_dir    : upload/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ out_dir   : results/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ status_in : /content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json
#    ❌ Error leyendo status.json → [Errno 2] No such file or directory: '/content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json'
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #2424 — listando subcarpetas…
#    Carpeta(s) detectada(s): ['d05756e5-bac2-4b99-b313-eacd4b067213']
#
# 🔍 Revisando carpeta d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ in_dir    : upload/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ out_dir   : results/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ status_in : /content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json
#    ❌ Error leyendo status.json → [Errno 2] No such file or directory: '/content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json'
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #2425 — listando subcarpetas…
#    Carpeta(s) detectada(s): ['d05756e5-bac2-4b99-b313-eacd4b067213']
#
# 🔍 Revisando carpeta d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ in_dir    : upload/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ out_dir   : results/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ status_in : /content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json
#    ❌ Error leyendo status.json → [Errno 2] No such file or directory: '/content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json'
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #2426 — listando subcarpetas…
#    Carpeta(s) detectada(s): ['d05756e5-bac2-4b99-b313-eacd4b067213']
#
# 🔍 Revisando carpeta d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ in_dir    : upload/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ out_dir   : results/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ status_in : /content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json
#    ❌ Error leyendo status.json → [Errno 2] No such file or directory: '/content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json'
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #2427 — listando subcarpetas…
#    Carpeta(s) detectada(s): ['d05756e5-bac2-4b99-b313-eacd4b067213']
#
# 🔍 Revisando carpeta d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ in_dir    : upload/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ out_dir   : results/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ status_in : /content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json
#    ❌ Error leyendo status.json → [Errno 2] No such file or directory: '/content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json'
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #2428 — listando subcarpetas…
#    Carpeta(s) detectada(s): ['d05756e5-bac2-4b99-b313-eacd4b067213']
#
# 🔍 Revisando carpeta d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ in_dir    : upload/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ out_dir   : results/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ status_in : /content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json
#    ❌ Error leyendo status.json → [Errno 2] No such file or directory: '/content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json'
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #2429 — listando subcarpetas…
#    Carpeta(s) detectada(s): ['d05756e5-bac2-4b99-b313-eacd4b067213']
#
# 🔍 Revisando carpeta d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ in_dir    : upload/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ out_dir   : results/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ status_in : /content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json
#    ❌ Error leyendo status.json → [Errno 2] No such file or directory: '/content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json'
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #2430 — listando subcarpetas…
#    Carpeta(s) detectada(s): ['d05756e5-bac2-4b99-b313-eacd4b067213']
#
# 🔍 Revisando carpeta d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ in_dir    : upload/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ out_dir   : results/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ status_in : /content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json
#    ❌ Error leyendo status.json → [Errno 2] No such file or directory: '/content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json'
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #2431 — listando subcarpetas…
#    Carpeta(s) detectada(s): ['d05756e5-bac2-4b99-b313-eacd4b067213']
#
# 🔍 Revisando carpeta d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ in_dir    : upload/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ out_dir   : results/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ status_in : /content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json
#    ❌ Error leyendo status.json → [Errno 2] No such file or directory: '/content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json'
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #2432 — listando subcarpetas…
#    Carpeta(s) detectada(s): ['d05756e5-bac2-4b99-b313-eacd4b067213']
#
# 🔍 Revisando carpeta d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ in_dir    : upload/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ out_dir   : results/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ status_in : /content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json
#    ❌ Error leyendo status.json → [Errno 2] No such file or directory: '/content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json'
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #2433 — listando subcarpetas…
#    Carpeta(s) detectada(s): ['d05756e5-bac2-4b99-b313-eacd4b067213']
#
# 🔍 Revisando carpeta d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ in_dir    : upload/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ out_dir   : results/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ status_in : /content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json
#    ❌ Error leyendo status.json → [Errno 2] No such file or directory: '/content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json'
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #2434 — listando subcarpetas…
#    Carpeta(s) detectada(s): ['d05756e5-bac2-4b99-b313-eacd4b067213']
#
# 🔍 Revisando carpeta d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ in_dir    : upload/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ out_dir   : results/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ status_in : /content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json
#    ❌ Error leyendo status.json → [Errno 2] No such file or directory: '/content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json'
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #2435 — listando subcarpetas…
#    Carpeta(s) detectada(s): ['d05756e5-bac2-4b99-b313-eacd4b067213']
#
# 🔍 Revisando carpeta d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ in_dir    : upload/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ out_dir   : results/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ status_in : /content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json
#    ❌ Error leyendo status.json → [Errno 2] No such file or directory: '/content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json'
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #2436 — listando subcarpetas…
#    Carpeta(s) detectada(s): ['d05756e5-bac2-4b99-b313-eacd4b067213']
#
# 🔍 Revisando carpeta d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ in_dir    : upload/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ out_dir   : results/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ status_in : /content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json
#    ❌ Error leyendo status.json → [Errno 2] No such file or directory: '/content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json'
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #2437 — listando subcarpetas…
#    Carpeta(s) detectada(s): ['d05756e5-bac2-4b99-b313-eacd4b067213']
#
# 🔍 Revisando carpeta d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ in_dir    : upload/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ out_dir   : results/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ status_in : /content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json
#    ❌ Error leyendo status.json → [Errno 2] No such file or directory: '/content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json'
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #2438 — listando subcarpetas…
#    Carpeta(s) detectada(s): ['d05756e5-bac2-4b99-b313-eacd4b067213']
#
# 🔍 Revisando carpeta d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ in_dir    : upload/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ out_dir   : results/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ status_in : /content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json
#    ❌ Error leyendo status.json → [Errno 2] No such file or directory: '/content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json'
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #2439 — listando subcarpetas…
#    Carpeta(s) detectada(s): ['d05756e5-bac2-4b99-b313-eacd4b067213']
#
# 🔍 Revisando carpeta d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ in_dir    : upload/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ out_dir   : results/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ status_in : /content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json
#    ❌ Error leyendo status.json → [Errno 2] No such file or directory: '/content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json'
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #2440 — listando subcarpetas…
#    Carpeta(s) detectada(s): ['d05756e5-bac2-4b99-b313-eacd4b067213']
#
# 🔍 Revisando carpeta d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ in_dir    : upload/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ out_dir   : results/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ status_in : /content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json
#    ❌ Error leyendo status.json → [Errno 2] No such file or directory: '/content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json'
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #2441 — listando subcarpetas…
#    Carpeta(s) detectada(s): ['d05756e5-bac2-4b99-b313-eacd4b067213']
#
# 🔍 Revisando carpeta d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ in_dir    : upload/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ out_dir   : results/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ status_in : /content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json
#    ❌ Error leyendo status.json → [Errno 2] No such file or directory: '/content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json'
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #2442 — listando subcarpetas…
#    Carpeta(s) detectada(s): ['d05756e5-bac2-4b99-b313-eacd4b067213']
#
# 🔍 Revisando carpeta d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ in_dir    : upload/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ out_dir   : results/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ status_in : /content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json
#    ❌ Error leyendo status.json → [Errno 2] No such file or directory: '/content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json'
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #2443 — listando subcarpetas…
#    Carpeta(s) detectada(s): ['d05756e5-bac2-4b99-b313-eacd4b067213']
#
# 🔍 Revisando carpeta d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ in_dir    : upload/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ out_dir   : results/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ status_in : /content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json
#    ❌ Error leyendo status.json → [Errno 2] No such file or directory: '/content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json'
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #2444 — listando subcarpetas…
#    Carpeta(s) detectada(s): ['d05756e5-bac2-4b99-b313-eacd4b067213']
#
# 🔍 Revisando carpeta d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ in_dir    : upload/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ out_dir   : results/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ status_in : /content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json
#    ❌ Error leyendo status.json → [Errno 2] No such file or directory: '/content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json'
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #2445 — listando subcarpetas…
#    Carpeta(s) detectada(s): ['d05756e5-bac2-4b99-b313-eacd4b067213']
#
# 🔍 Revisando carpeta d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ in_dir    : upload/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ out_dir   : results/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ status_in : /content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json
#    ❌ Error leyendo status.json → [Errno 2] No such file or directory: '/content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json'
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #2446 — listando subcarpetas…
#    Carpeta(s) detectada(s): ['d05756e5-bac2-4b99-b313-eacd4b067213']
#
# 🔍 Revisando carpeta d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ in_dir    : upload/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ out_dir   : results/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ status_in : /content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json
#    ❌ Error leyendo status.json → [Errno 2] No such file or directory: '/content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json'
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #2447 — listando subcarpetas…
#    Carpeta(s) detectada(s): ['d05756e5-bac2-4b99-b313-eacd4b067213']
#
# 🔍 Revisando carpeta d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ in_dir    : upload/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ out_dir   : results/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ status_in : /content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json
#    ❌ Error leyendo status.json → [Errno 2] No such file or directory: '/content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json'
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #2448 — listando subcarpetas…
#    Carpeta(s) detectada(s): ['d05756e5-bac2-4b99-b313-eacd4b067213']
#
# 🔍 Revisando carpeta d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ in_dir    : upload/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ out_dir   : results/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ status_in : /content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json
#    ❌ Error leyendo status.json → [Errno 2] No such file or directory: '/content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json'
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #2449 — listando subcarpetas…
#    Carpeta(s) detectada(s): ['d05756e5-bac2-4b99-b313-eacd4b067213']
#
# 🔍 Revisando carpeta d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ in_dir    : upload/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ out_dir   : results/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ status_in : /content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json
#    ❌ Error leyendo status.json → [Errno 2] No such file or directory: '/content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json'
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #2450 — listando subcarpetas…
#    Carpeta(s) detectada(s): ['d05756e5-bac2-4b99-b313-eacd4b067213']
#
# 🔍 Revisando carpeta d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ in_dir    : upload/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ out_dir   : results/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ status_in : /content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json
#    ❌ Error leyendo status.json → [Errno 2] No such file or directory: '/content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json'
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #2451 — listando subcarpetas…
#    Carpeta(s) detectada(s): ['d05756e5-bac2-4b99-b313-eacd4b067213']
#
# 🔍 Revisando carpeta d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ in_dir    : upload/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ out_dir   : results/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ status_in : /content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json
#    ❌ Error leyendo status.json → [Errno 2] No such file or directory: '/content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json'
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #2452 — listando subcarpetas…
#    Carpeta(s) detectada(s): ['d05756e5-bac2-4b99-b313-eacd4b067213']
#
# 🔍 Revisando carpeta d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ in_dir    : upload/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ out_dir   : results/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ status_in : /content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json
#    ❌ Error leyendo status.json → [Errno 2] No such file or directory: '/content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json'
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #2453 — listando subcarpetas…
#    Carpeta(s) detectada(s): ['d05756e5-bac2-4b99-b313-eacd4b067213']
#
# 🔍 Revisando carpeta d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ in_dir    : upload/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ out_dir   : results/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ status_in : /content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json
#    ❌ Error leyendo status.json → [Errno 2] No such file or directory: '/content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json'
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #2454 — listando subcarpetas…
#    Carpeta(s) detectada(s): ['d05756e5-bac2-4b99-b313-eacd4b067213']
#
# 🔍 Revisando carpeta d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ in_dir    : upload/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ out_dir   : results/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ status_in : /content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json
#    ❌ Error leyendo status.json → [Errno 2] No such file or directory: '/content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json'
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #2455 — listando subcarpetas…
#    Carpeta(s) detectada(s): ['d05756e5-bac2-4b99-b313-eacd4b067213']
#
# 🔍 Revisando carpeta d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ in_dir    : upload/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ out_dir   : results/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ status_in : /content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json
#    ❌ Error leyendo status.json → [Errno 2] No such file or directory: '/content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json'
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #2456 — listando subcarpetas…
#    Carpeta(s) detectada(s): ['d05756e5-bac2-4b99-b313-eacd4b067213']
#
# 🔍 Revisando carpeta d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ in_dir    : upload/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ out_dir   : results/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ status_in : /content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json
#    ❌ Error leyendo status.json → [Errno 2] No such file or directory: '/content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json'
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #2457 — listando subcarpetas…
#    Carpeta(s) detectada(s): ['d05756e5-bac2-4b99-b313-eacd4b067213']
#
# 🔍 Revisando carpeta d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ in_dir    : upload/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ out_dir   : results/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ status_in : /content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json
#    ❌ Error leyendo status.json → [Errno 2] No such file or directory: '/content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json'
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #2458 — listando subcarpetas…
#    Carpeta(s) detectada(s): ['d05756e5-bac2-4b99-b313-eacd4b067213']
#
# 🔍 Revisando carpeta d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ in_dir    : upload/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ out_dir   : results/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ status_in : /content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json
#    ❌ Error leyendo status.json → [Errno 2] No such file or directory: '/content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json'
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #2459 — listando subcarpetas…
#    Carpeta(s) detectada(s): ['d05756e5-bac2-4b99-b313-eacd4b067213']
#
# 🔍 Revisando carpeta d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ in_dir    : upload/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ out_dir   : results/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ status_in : /content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json
#    ❌ Error leyendo status.json → [Errno 2] No such file or directory: '/content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json'
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #2460 — listando subcarpetas…
#    Carpeta(s) detectada(s): ['d05756e5-bac2-4b99-b313-eacd4b067213']
#
# 🔍 Revisando carpeta d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ in_dir    : upload/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ out_dir   : results/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ status_in : /content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json
#    ❌ Error leyendo status.json → [Errno 2] No such file or directory: '/content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json'
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #2461 — listando subcarpetas…
#    Carpeta(s) detectada(s): ['d05756e5-bac2-4b99-b313-eacd4b067213']
#
# 🔍 Revisando carpeta d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ in_dir    : upload/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ out_dir   : results/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ status_in : /content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json
#    ❌ Error leyendo status.json → [Errno 2] No such file or directory: '/content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json'
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #2462 — listando subcarpetas…
#    Carpeta(s) detectada(s): ['d05756e5-bac2-4b99-b313-eacd4b067213']
#
# 🔍 Revisando carpeta d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ in_dir    : upload/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ out_dir   : results/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ status_in : /content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json
#    ❌ Error leyendo status.json → [Errno 2] No such file or directory: '/content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json'
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #2463 — listando subcarpetas…
#    Carpeta(s) detectada(s): ['d05756e5-bac2-4b99-b313-eacd4b067213']
#
# 🔍 Revisando carpeta d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ in_dir    : upload/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ out_dir   : results/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ status_in : /content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json
#    ❌ Error leyendo status.json → [Errno 2] No such file or directory: '/content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json'
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #2464 — listando subcarpetas…
#    Carpeta(s) detectada(s): ['d05756e5-bac2-4b99-b313-eacd4b067213']
#
# 🔍 Revisando carpeta d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ in_dir    : upload/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ out_dir   : results/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ status_in : /content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json
#    ❌ Error leyendo status.json → [Errno 2] No such file or directory: '/content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json'
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #2465 — listando subcarpetas…
#    Carpeta(s) detectada(s): ['d05756e5-bac2-4b99-b313-eacd4b067213']
#
# 🔍 Revisando carpeta d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ in_dir    : upload/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ out_dir   : results/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ status_in : /content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json
#    ❌ Error leyendo status.json → [Errno 2] No such file or directory: '/content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json'
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #2466 — listando subcarpetas…
#    Carpeta(s) detectada(s): ['d05756e5-bac2-4b99-b313-eacd4b067213']
#
# 🔍 Revisando carpeta d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ in_dir    : upload/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ out_dir   : results/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ status_in : /content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json
#    ❌ Error leyendo status.json → [Errno 2] No such file or directory: '/content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json'
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #2467 — listando subcarpetas…
#    Carpeta(s) detectada(s): ['d05756e5-bac2-4b99-b313-eacd4b067213']
#
# 🔍 Revisando carpeta d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ in_dir    : upload/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ out_dir   : results/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ status_in : /content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json
#    ❌ Error leyendo status.json → [Errno 2] No such file or directory: '/content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json'
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #2468 — listando subcarpetas…
#    Carpeta(s) detectada(s): ['d05756e5-bac2-4b99-b313-eacd4b067213']
#
# 🔍 Revisando carpeta d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ in_dir    : upload/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ out_dir   : results/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ status_in : /content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json
#    ❌ Error leyendo status.json → [Errno 2] No such file or directory: '/content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json'
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #2469 — listando subcarpetas…
#    Carpeta(s) detectada(s): ['d05756e5-bac2-4b99-b313-eacd4b067213']
#
# 🔍 Revisando carpeta d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ in_dir    : upload/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ out_dir   : results/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ status_in : /content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json
#    ❌ Error leyendo status.json → [Errno 2] No such file or directory: '/content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json'
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #2470 — listando subcarpetas…
#    Carpeta(s) detectada(s): ['d05756e5-bac2-4b99-b313-eacd4b067213']
#
# 🔍 Revisando carpeta d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ in_dir    : upload/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ out_dir   : results/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ status_in : /content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json
#    ❌ Error leyendo status.json → [Errno 2] No such file or directory: '/content/drive/MyDrive/TexScaling/Real-ESRGAN/upload/d05756e5-bac2-4b99-b313-eacd4b067213/status.json'
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #2471 — listando subcarpetas…
#    Carpeta(s) detectada(s): ['d05756e5-bac2-4b99-b313-eacd4b067213']
#
# 🔍 Revisando carpeta d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ in_dir    : upload/d05756e5-bac2-4b99-b313-eacd4b067213
#    ↳ out_dir   : results/d05756e5-bac2-4b99-b313-eacd4b067213
# ...
#
# 🔄 Iteración #2950 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #2951 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #2952 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #2953 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #2954 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #2955 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #2956 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #2957 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #2958 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #2959 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #2960 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #2961 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #2962 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #2963 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #2964 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #2965 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #2966 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #2967 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #2968 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #2969 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #2970 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #2971 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #2972 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #2973 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #2974 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #2975 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #2976 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #2977 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #2978 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #2979 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #2980 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #2981 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #2982 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #2983 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #2984 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #2985 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #2986 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #2987 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #2988 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #2989 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #2990 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #2991 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #2992 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #2993 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #2994 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #2995 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #2996 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #2997 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #2998 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #2999 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #3000 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #3001 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #3002 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #3003 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #3004 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #3005 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #3006 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #3007 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #3008 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #3009 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #3010 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #3011 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #3012 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #3013 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #3014 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #3015 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #3016 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #3017 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #3018 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #3019 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #3020 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #3021 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #3022 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #3023 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #3024 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #3025 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #3026 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #3027 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #3028 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #3029 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #3030 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #3031 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #3032 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #3033 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #3034 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #3035 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #3036 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #3037 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #3038 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #3039 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #3040 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #3041 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #3042 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #3043 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #3044 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #3045 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #3046 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #3047 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #3048 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #3049 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #3050 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #3051 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #3052 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #3053 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #3054 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #3055 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #3056 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #3057 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #3058 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #3059 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #3060 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #3061 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #3062 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #3063 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #3064 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #3065 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #3066 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #3067 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #3068 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #3069 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #3070 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #3071 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #3072 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #3073 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #3074 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #3075 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #3076 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #3077 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #3078 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #3079 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #3080 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #3081 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #3082 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #3083 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #3084 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #3085 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #3086 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #3087 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
#
# 🔄 Iteración #3088 — listando subcarpetas…
#    Carpeta(s) detectada(s): ninguna
#    ⏳ Nada para procesar, esperando…
